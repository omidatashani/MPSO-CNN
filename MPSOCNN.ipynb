# %%
import math
import random
import numpy as np
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import cifar10, cifar100, mnist
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dropout
import pywt
from datetime import datetime

# Load MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Reshape and normalize data
train_images = train_images.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1)).astype('float32') / 255
# Convert labels to one-hot encoded format
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
# Split the training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2)

gbests_fitnesses_l2 = []

def sigmoid(t):
    return 1 / (1 + math.exp(10*t - 2))

def wavelet_mutation(particle):
    # Here we use 'db2' wavelet, but different wavelets can be experimented with
    (cA, cD) = pywt.dwt(particle, 'db2')
    # Adding Gaussian noise to the approximation coefficients
    cA += np.random.normal(0, 0.1, len(cA))
    # Inverse DWT to get the mutated particle
    return pywt.idwt(cA, cD, 'db2')

def create_model(params, conv_layers, pool_layers, dense_layers):
    stride_size_conv = int(params[0])
    filter_size_conv = int(params[1])
    stride_size_pool = int(params[2])
    filter_size_pool = int(params[3])
    padding_pixels_conv = 'same' if int(params[4]) == 1 else 'valid'
    padding_pixels_pool = 'same' if int(params[5]) == 1 else 'valid'
    num_filters = int(params[6])
    num_neurons = int(params[7])

    input_size = 28  # size of the input images

    model = Sequential()

    # Add convolutional layers
    for _ in range(conv_layers):
      if input_size - filter_size_conv < 0:
            break
      model.add(Conv2D(filters=num_filters, kernel_size=(filter_size_conv, filter_size_conv), strides=(stride_size_conv, stride_size_conv), padding=padding_pixels_conv, activation='relu'))
      model.add(Dropout(0.2))  # 20% Dropout
      input_size = (input_size - filter_size_conv) // stride_size_conv + 1

    # Add pooling layers
    for _ in range(pool_layers):
      if input_size - filter_size_pool < 0:
            break
      model.add(MaxPooling2D(pool_size=(filter_size_pool, filter_size_pool), strides=(stride_size_pool, stride_size_pool), padding=padding_pixels_pool))
      input_size = (input_size - filter_size_pool) // stride_size_pool + 1

    if input_size > 0:
        model.add(Flatten())

        # Fully Connected Layers
        for _ in range(dense_layers):
            model.add(Dense(units=num_neurons, activation='relu'))
            model.add(Dropout(0.2))  # 20% Dropout

        model.add(Dense(10, activation='softmax'))

        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    else:
        model = None

    return model

def compute_fitness(model,it,par,t,j):
    print("iteration1:",it," particle1:",par,"iteration2:",t," particle2:",j)
    history = model.fit(train_images, train_labels, epochs=1, batch_size=128, validation_data=(val_images, val_labels))  # Use mini-batch size of 128
    accuracy = history.history['val_accuracy'][-1]  # Get the validation accuracy of the last epoch
    return accuracy

def update_velocity_position(particle, pbest, gbest, omega, fitness, fitness_values):
    r_p, r_g = np.random.rand(len(particle)), np.random.rand(len(particle))
    velocity = omega * particle + 2 * r_p * (pbest - particle) + 2 * r_g * (gbest - particle)
    new_particle = particle + velocity

    # Ensure the particle parameters remain within valid bounds
    new_particle[0:4] = np.clip(new_particle[0:4], 1, 13)  # stride_size_conv, filter_size_conv, stride_size_pool, filter_size_pool
    new_particle[0] = np.clip(new_particle[0], 1, 5)
    new_particle[2] = np.clip(new_particle[2], 1, 5)
    new_particle[4:6] = np.clip(new_particle[4:6], 0, 1)   # padding_pixels_conv, padding_pixels_pool
    new_particle[6] = np.clip(new_particle[6], 1, 64)      # num_filters
    new_particle[7] = np.clip(new_particle[7], 1, 1024)    # num_neurons

    if fitness < np.percentile(fitness_values, 25):
        new_particle = wavelet_mutation(new_particle)

    new_particle = np.round(new_particle)

    return new_particle

def update_personal_best(particles, fitness_values, personal_best_positions, personal_best_fitnesses):
    better_mask = fitness_values > personal_best_fitnesses
    personal_best_positions[better_mask] = particles[better_mask]
    personal_best_fitnesses[better_mask] = fitness_values[better_mask]
    return personal_best_positions, personal_best_fitnesses

def hybrid_MPSO_CNN_level2(particle, t_max2, omega, conv_layers, pool_layers, dense_layers, it, par):
    n = 3
    low = [1, 1, 1, 1, 0, 0, 1, 1]
    high = [5, 13, 5, 13, 1, 1, 64, 1024]
    particles = np.random.uniform(low=low, high=high, size=(n, len(low)))
    fitness_values = np.zeros(n)
    personal_best_positions = particles.copy()
    personal_best_fitnesses = fitness_values.copy()

    gbest_index = np.random.randint(n)  # Choose a random index for gbest
    gbest = particles[gbest_index].copy()
    gbest_fitness = 0

    for t in range(t_max2):
        for j in range(n):
            particles[j] = update_velocity_position(particles[j], personal_best_positions[j], gbest, omega, fitness_values[j], fitness_values)
            particles[j]=np.round(particles[j])
            CNN_model = create_model(particles[j], conv_layers, pool_layers, dense_layers)
            if CNN_model is None:
                continue
            fitness_values[j] = compute_fitness(CNN_model,it,par,t,j)
            personal_best_positions, personal_best_fitnesses = update_personal_best(particles, fitness_values, personal_best_positions, personal_best_fitnesses)
            if np.max(personal_best_fitnesses) > gbest_fitness:
                gbest = personal_best_positions[np.argmax(personal_best_fitnesses)]
                gbest_fitness = np.max(personal_best_fitnesses)
                gbests_fitnesses_l2.append(gbest_fitness)

    return gbest, gbest_fitness

def hybrid_MPSO_CNN_level1(t_max1, m):
    alpha = 0.5
    low = [1, 1, 1]
    high = [5, 5, 5]
    particles = np.random.uniform(low=low, high=high, size=(m, len(low)))  # Initialize particle positions in specified range
    fitness_values = np.zeros(m)
    personal_best_positions = particles.copy()
    personal_best_fitnesses = fitness_values.copy()

    gbest_index = np.random.randint(m)  # Choose a random index for gbest
    gbest = particles[gbest_index].copy()
    gbest_fitness = 0

    # Initializing list to store gbest_fitness for each iteration
    gbests_fitnesses_l1 = []

    for i in range(t_max1):
        if i < alpha*t_max1:
            omega = 0.9
        else:
            omega = sigmoid(i/t_max1)
        for j in range(m):
            particles = np.round(particles)
            num_conv_layers = int(particles[j][0])
            num_pool_layers = int(particles[j][1])
            num_dense_layers = int(particles[j][2])
            gbestl2, temp_fitness = hybrid_MPSO_CNN_level2(particles[j], t_max2=3, omega=omega, conv_layers=num_conv_layers, pool_layers=num_pool_layers, dense_layers=num_dense_layers, it=i, par=j)
            fitness_values[j] = temp_fitness
            personal_best_positions, personal_best_fitnesses = update_personal_best(particles, fitness_values, personal_best_positions, personal_best_fitnesses)
            if np.max(personal_best_fitnesses) > gbest_fitness:
                gbest = personal_best_positions[np.argmax(personal_best_fitnesses)]
                gbest_fitness = np.max(personal_best_fitnesses)
                gbests_fitnesses_l1.append(gbest_fitness)
                gbest_l2 = gbestl2

            r_p, r_g = np.random.rand(len(particles[j])), np.random.rand(len(particles[j]))
            velocity = omega * particles[j] + 2 * r_p * (personal_best_positions[j] - particles[j]) + 2 * r_g * (gbest - particles[j])
            particles[j] = particles[j] + velocity

            particles[j] = np.round(particles[j])

            particles[j] = np.clip(particles[j], 1, 5)

    return gbest, gbest_l2, gbest_fitness, gbests_fitnesses_l1

# %%
# Running the hybrid PSO-CNN optimization
start_time = datetime.now()
gbest, gbest_l2, gbest_fitness, gbests_fitnesses_l1 = hybrid_MPSO_CNN_level1(t_max1=3, m=3)
end_time = datetime.now()
print(f"Global Best Particle: {gbest} {gbest_l2}\nGlobal Best Fitness (Accuracy): {gbest_fitness}")
print("total time is %s" % (str(end_time - start_time)))
# Out:
# iteration1: 0  particle1: 0 iteration2: 0  particle2: 0
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2444 - accuracy: 0.9235 - val_loss: 0.1031 - val_accuracy: 0.9699
# iteration1: 0  particle1: 0 iteration2: 0  particle2: 1
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2625 - accuracy: 0.9168 - val_loss: 0.1081 - val_accuracy: 0.9682
# iteration1: 0  particle1: 0 iteration2: 0  particle2: 2
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2589 - accuracy: 0.9190 - val_loss: 0.1186 - val_accuracy: 0.9657
# iteration1: 0  particle1: 0 iteration2: 1  particle2: 0
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2607 - accuracy: 0.9172 - val_loss: 0.1066 - val_accuracy: 0.9674
# iteration1: 0  particle1: 0 iteration2: 1  particle2: 1
# 375/375 [==============================] - 4s 6ms/step - loss: 0.2607 - accuracy: 0.9181 - val_loss: 0.0988 - val_accuracy: 0.9698
# iteration1: 0  particle1: 0 iteration2: 1  particle2: 2
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2603 - accuracy: 0.9179 - val_loss: 0.1055 - val_accuracy: 0.9684
# iteration1: 0  particle1: 0 iteration2: 2  particle2: 0
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2621 - accuracy: 0.9168 - val_loss: 0.1056 - val_accuracy: 0.9691
# iteration1: 0  particle1: 0 iteration2: 2  particle2: 1
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2641 - accuracy: 0.9160 - val_loss: 0.0989 - val_accuracy: 0.9702
# iteration1: 0  particle1: 0 iteration2: 2  particle2: 2
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2577 - accuracy: 0.9192 - val_loss: 0.1541 - val_accuracy: 0.9561
# iteration1: 0  particle1: 1 iteration2: 0  particle2: 0
# 375/375 [==============================] - 4s 5ms/step - loss: 0.2402 - accuracy: 0.9273 - val_loss: 0.0924 - val_accuracy: 0.9728
# iteration1: 0  particle1: 1 iteration2: 0  particle2: 1
# 375/375 [==============================] - 4s 5ms/step - loss: 0.2502 - accuracy: 0.9236 - val_loss: 0.0915 - val_accuracy: 0.9711
# iteration1: 0  particle1: 1 iteration2: 0  particle2: 2
# 375/375 [==============================] - 4s 5ms/step - loss: 0.2439 - accuracy: 0.9227 - val_loss: 0.0936 - val_accuracy: 0.9707
# iteration1: 0  particle1: 1 iteration2: 1  particle2: 0
# 375/375 [==============================] - 4s 5ms/step - loss: 0.2495 - accuracy: 0.9223 - val_loss: 0.0932 - val_accuracy: 0.9711
# iteration1: 0  particle1: 1 iteration2: 1  particle2: 1
# 375/375 [==============================] - 3s 5ms/step - loss: 0.2434 - accuracy: 0.9250 - val_loss: 0.1022 - val_accuracy: 0.9698
# iteration1: 0  particle1: 1 iteration2: 1  particle2: 2
# 375/375 [==============================] - 4s 5ms/step - loss: 0.2410 - accuracy: 0.9260 - val_loss: 0.0906 - val_accuracy: 0.9718
# iteration1: 0  particle1: 1 iteration2: 2  particle2: 0
# 375/375 [==============================] - 3s 5ms/step - loss: 0.2484 - accuracy: 0.9236 - val_loss: 0.1117 - val_accuracy: 0.9655
# iteration1: 0  particle1: 1 iteration2: 2  particle2: 1
# 375/375 [==============================] - 3s 5ms/step - loss: 0.2449 - accuracy: 0.9269 - val_loss: 0.0907 - val_accuracy: 0.9713
# iteration1: 0  particle1: 1 iteration2: 2  particle2: 2
# 375/375 [==============================] - 4s 5ms/step - loss: 0.2508 - accuracy: 0.9240 - val_loss: 0.1084 - val_accuracy: 0.9658
# iteration1: 0  particle1: 2 iteration2: 0  particle2: 0
# 375/375 [==============================] - 4s 5ms/step - loss: 0.2057 - accuracy: 0.9368 - val_loss: 0.0856 - val_accuracy: 0.9740
# iteration1: 0  particle1: 2 iteration2: 0  particle2: 1
# 375/375 [==============================] - 4s 5ms/step - loss: 0.2115 - accuracy: 0.9352 - val_loss: 0.0787 - val_accuracy: 0.9753
# iteration1: 0  particle1: 2 iteration2: 0  particle2: 2
# 375/375 [==============================] - 4s 5ms/step - loss: 0.2304 - accuracy: 0.9293 - val_loss: 0.0995 - val_accuracy: 0.9696
# iteration1: 0  particle1: 2 iteration2: 1  particle2: 0
# 375/375 [==============================] - 3s 5ms/step - loss: 0.2320 - accuracy: 0.9313 - val_loss: 0.0960 - val_accuracy: 0.9697
# iteration1: 0  particle1: 2 iteration2: 1  particle2: 1
# 375/375 [==============================] - 3s 5ms/step - loss: 0.2344 - accuracy: 0.9287 - val_loss: 0.0966 - val_accuracy: 0.9707
# iteration1: 0  particle1: 2 iteration2: 1  particle2: 2
# 375/375 [==============================] - 3s 5ms/step - loss: 0.2295 - accuracy: 0.9290 - val_loss: 0.0876 - val_accuracy: 0.9732
# iteration1: 0  particle1: 2 iteration2: 2  particle2: 0
# 375/375 [==============================] - 3s 5ms/step - loss: 0.2289 - accuracy: 0.9303 - val_loss: 0.0924 - val_accuracy: 0.9703
# iteration1: 0  particle1: 2 iteration2: 2  particle2: 1
# 375/375 [==============================] - 4s 5ms/step - loss: 0.2308 - accuracy: 0.9269 - val_loss: 0.1121 - val_accuracy: 0.9648
# iteration1: 0  particle1: 2 iteration2: 2  particle2: 2
# 375/375 [==============================] - 4s 5ms/step - loss: 0.2313 - accuracy: 0.9273 - val_loss: 0.0878 - val_accuracy: 0.9723
# iteration1: 1  particle1: 0 iteration2: 0  particle2: 0
# 375/375 [==============================] - 5s 6ms/step - loss: 0.3827 - accuracy: 0.8793 - val_loss: 0.1225 - val_accuracy: 0.9646
# iteration1: 1  particle1: 0 iteration2: 0  particle2: 1
# 375/375 [==============================] - 5s 6ms/step - loss: 0.3130 - accuracy: 0.9013 - val_loss: 0.1404 - val_accuracy: 0.9623
# iteration1: 1  particle1: 0 iteration2: 0  particle2: 2
# 375/375 [==============================] - 6s 8ms/step - loss: 0.3797 - accuracy: 0.8800 - val_loss: 0.1279 - val_accuracy: 0.9632
# iteration1: 1  particle1: 0 iteration2: 1  particle2: 0
# 375/375 [==============================] - 5s 6ms/step - loss: 0.3312 - accuracy: 0.8957 - val_loss: 0.1234 - val_accuracy: 0.9656
# iteration1: 1  particle1: 0 iteration2: 1  particle2: 1
# 375/375 [==============================] - 5s 6ms/step - loss: 0.3053 - accuracy: 0.9040 - val_loss: 0.1539 - val_accuracy: 0.9610
# iteration1: 1  particle1: 0 iteration2: 1  particle2: 2
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2977 - accuracy: 0.9074 - val_loss: 0.1312 - val_accuracy: 0.9628
# iteration1: 1  particle1: 0 iteration2: 2  particle2: 0
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2988 - accuracy: 0.9079 - val_loss: 0.1175 - val_accuracy: 0.9659
# iteration1: 1  particle1: 0 iteration2: 2  particle2: 1
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2984 - accuracy: 0.9071 - val_loss: 0.1215 - val_accuracy: 0.9665
# iteration1: 1  particle1: 0 iteration2: 2  particle2: 2
# 375/375 [==============================] - 5s 6ms/step - loss: 0.3000 - accuracy: 0.9064 - val_loss: 0.1124 - val_accuracy: 0.9679
# iteration1: 1  particle1: 1 iteration2: 0  particle2: 0
# 375/375 [==============================] - 5s 6ms/step - loss: 0.4050 - accuracy: 0.8708 - val_loss: 0.0937 - val_accuracy: 0.9742
# iteration1: 1  particle1: 1 iteration2: 0  particle2: 1
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2836 - accuracy: 0.9097 - val_loss: 0.1129 - val_accuracy: 0.9675
# iteration1: 1  particle1: 1 iteration2: 0  particle2: 2
# 375/375 [==============================] - 5s 5ms/step - loss: 0.3623 - accuracy: 0.8835 - val_loss: 0.1210 - val_accuracy: 0.9634
# iteration1: 1  particle1: 1 iteration2: 1  particle2: 0
# 375/375 [==============================] - 5s 6ms/step - loss: 0.3639 - accuracy: 0.8835 - val_loss: 0.1157 - val_accuracy: 0.9672
# iteration1: 1  particle1: 1 iteration2: 1  particle2: 1
# 375/375 [==============================] - 5s 5ms/step - loss: 0.2848 - accuracy: 0.9095 - val_loss: 0.1095 - val_accuracy: 0.9682
# iteration1: 1  particle1: 1 iteration2: 1  particle2: 2
# 375/375 [==============================] - 5s 5ms/step - loss: 0.3726 - accuracy: 0.8812 - val_loss: 0.1030 - val_accuracy: 0.9687
# iteration1: 1  particle1: 1 iteration2: 2  particle2: 0
# 375/375 [==============================] - 5s 5ms/step - loss: 0.4913 - accuracy: 0.8430 - val_loss: 0.1319 - val_accuracy: 0.9601
# iteration1: 1  particle1: 1 iteration2: 2  particle2: 1
# 375/375 [==============================] - 5s 5ms/step - loss: 0.2419 - accuracy: 0.9230 - val_loss: 0.0956 - val_accuracy: 0.9698
# iteration1: 1  particle1: 1 iteration2: 2  particle2: 2
# 375/375 [==============================] - 5s 5ms/step - loss: 0.3241 - accuracy: 0.8964 - val_loss: 0.1056 - val_accuracy: 0.9664
# iteration1: 1  particle1: 2 iteration2: 0  particle2: 0
# 375/375 [==============================] - 5s 5ms/step - loss: 0.3513 - accuracy: 0.8875 - val_loss: 0.0955 - val_accuracy: 0.9717
# iteration1: 1  particle1: 2 iteration2: 0  particle2: 1
# 375/375 [==============================] - 5s 6ms/step - loss: 0.3017 - accuracy: 0.9044 - val_loss: 0.1043 - val_accuracy: 0.9673
# iteration1: 1  particle1: 2 iteration2: 0  particle2: 2
# 375/375 [==============================] - 5s 8ms/step - loss: 0.2653 - accuracy: 0.9146 - val_loss: 0.1197 - val_accuracy: 0.9632
# iteration1: 1  particle1: 2 iteration2: 1  particle2: 0
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2837 - accuracy: 0.9116 - val_loss: 0.0998 - val_accuracy: 0.9700
# iteration1: 1  particle1: 2 iteration2: 1  particle2: 1
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2709 - accuracy: 0.9158 - val_loss: 0.1013 - val_accuracy: 0.9693
# iteration1: 1  particle1: 2 iteration2: 1  particle2: 2
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2589 - accuracy: 0.9191 - val_loss: 0.1128 - val_accuracy: 0.9670
# iteration1: 1  particle1: 2 iteration2: 2  particle2: 0
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2976 - accuracy: 0.9058 - val_loss: 0.1043 - val_accuracy: 0.9672
# iteration1: 1  particle1: 2 iteration2: 2  particle2: 1
# 375/375 [==============================] - 4s 6ms/step - loss: 0.2629 - accuracy: 0.9176 - val_loss: 0.1068 - val_accuracy: 0.9672
# iteration1: 1  particle1: 2 iteration2: 2  particle2: 2
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2916 - accuracy: 0.9085 - val_loss: 0.1158 - val_accuracy: 0.9629
# iteration1: 2  particle1: 0 iteration2: 0  particle2: 0
# 375/375 [==============================] - 7s 10ms/step - loss: 0.3505 - accuracy: 0.8834 - val_loss: 0.0862 - val_accuracy: 0.9753
# iteration1: 2  particle1: 0 iteration2: 0  particle2: 1
# 375/375 [==============================] - 5s 7ms/step - loss: 0.3076 - accuracy: 0.9034 - val_loss: 0.1423 - val_accuracy: 0.9604
# iteration1: 2  particle1: 1 iteration2: 2  particle2: 2
# 375/375 [==============================] - 5s 6ms/step - loss: 0.3190 - accuracy: 0.8998 - val_loss: 0.1164 - val_accuracy: 0.9667
# iteration1: 2  particle1: 2 iteration2: 0  particle2: 0
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2213 - accuracy: 0.9294 - val_loss: 0.0787 - val_accuracy: 0.9764
# iteration1: 2  particle1: 2 iteration2: 0  particle2: 1
# 375/375 [==============================] - 5s 8ms/step - loss: 0.2175 - accuracy: 0.9314 - val_loss: 0.0790 - val_accuracy: 0.9768
# iteration1: 2  particle1: 2 iteration2: 0  particle2: 2
# 375/375 [==============================] - 3s 5ms/step - loss: 0.3041 - accuracy: 0.9041 - val_loss: 0.1260 - val_accuracy: 0.9611
# iteration1: 2  particle1: 2 iteration2: 1  particle2: 0
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2146 - accuracy: 0.9320 - val_loss: 0.0621 - val_accuracy: 0.9808
# iteration1: 2  particle1: 2 iteration2: 1  particle2: 1
# 375/375 [==============================] - 4s 6ms/step - loss: 0.2326 - accuracy: 0.9275 - val_loss: 0.1035 - val_accuracy: 0.9676
# iteration1: 2  particle1: 2 iteration2: 1  particle2: 2
# 375/375 [==============================] - 5s 7ms/step - loss: 0.2810 - accuracy: 0.9078 - val_loss: 0.0687 - val_accuracy: 0.9771
# iteration1: 2  particle1: 2 iteration2: 2  particle2: 0
# 375/375 [==============================] - 4s 6ms/step - loss: 0.2072 - accuracy: 0.9349 - val_loss: 0.0732 - val_accuracy: 0.9783
# iteration1: 2  particle1: 2 iteration2: 2  particle2: 1
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2236 - accuracy: 0.9303 - val_loss: 0.0675 - val_accuracy: 0.9787
# iteration1: 2  particle1: 2 iteration2: 2  particle2: 2
# 375/375 [==============================] - 5s 6ms/step - loss: 0.1991 - accuracy: 0.9360 - val_loss: 0.0818 - val_accuracy: 0.9772
# Global Best Particle: [5. 2. 1.] [  1.   8.   1.   8.   0.   1.  32. 669.]
# Global Best Fitness (Accuracy): 0.9808333516120911
# total time is 0:07:21.467365

# %%
# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
# Reshape and normalize data
train_images = train_images.reshape((50000, 32, 32, 3)).astype('float32') / 255
test_images = test_images.reshape((10000, 32, 32, 3)).astype('float32') / 255
# Convert labels to one-hot encoded format
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
# Split the training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2)
def create_model(params, conv_layers, pool_layers, dense_layers):
    stride_size_conv = int(params[0])
    filter_size_conv = int(params[1])
    stride_size_pool = int(params[2])
    filter_size_pool = int(params[3])
    padding_pixels_conv = 'same' if int(params[4]) == 1 else 'valid'
    padding_pixels_pool = 'same' if int(params[5]) == 1 else 'valid'
    num_filters = int(params[6])
    num_neurons = int(params[7])

    input_size = 32  # size of the input images

    model = Sequential()

    # Add convolutional layers
    for _ in range(conv_layers):
      if input_size - filter_size_conv < 0:
            break
      model.add(Conv2D(filters=num_filters, kernel_size=(filter_size_conv, filter_size_conv), strides=(stride_size_conv, stride_size_conv), padding=padding_pixels_conv, activation='relu'))
      model.add(Dropout(0.2))  # 20% Dropout
      input_size = (input_size - filter_size_conv) // stride_size_conv + 1

    # Add pooling layers
    for _ in range(pool_layers):
      if input_size - filter_size_pool < 0:
            break
      model.add(MaxPooling2D(pool_size=(filter_size_pool, filter_size_pool), strides=(stride_size_pool, stride_size_pool), padding=padding_pixels_pool))
      input_size = (input_size - filter_size_pool) // stride_size_pool + 1

    if input_size > 0:
        model.add(Flatten())

        # Fully Connected Layers
        for _ in range(dense_layers):
            model.add(Dense(units=num_neurons, activation='relu'))
            model.add(Dropout(0.2))  # 20% Dropout

        model.add(Dense(10, activation='softmax'))

        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    else:
        model = None

    return model
# Running the hybrid PSO-CNN optimization
start_time = datetime.now()
gbest, gbest_l2, gbest_fitness, gbests_fitnesses_l1 = hybrid_MPSO_CNN_level1(t_max1=3, m=3)
end_time = datetime.now()
print(f"Global Best Particle: {gbest} {gbest_l2}\nGlobal Best Fitness (Accuracy): {gbest_fitness}")
print("total time is %s" % (str(end_time - start_time)))
# Out:
# iteration1: 0  particle1: 0 iteration2: 0  particle2: 0
# 313/313 [==============================] - 4s 6ms/step - loss: 1.8982 - accuracy: 0.3048 - val_loss: 1.7135 - val_accuracy: 0.3832
# iteration1: 0  particle1: 0 iteration2: 0  particle2: 1
# 313/313 [==============================] - 4s 7ms/step - loss: 1.8953 - accuracy: 0.3016 - val_loss: 1.6705 - val_accuracy: 0.3958
# iteration1: 0  particle1: 0 iteration2: 0  particle2: 2
# 313/313 [==============================] - 4s 8ms/step - loss: 1.8162 - accuracy: 0.3377 - val_loss: 1.6278 - val_accuracy: 0.4069
# iteration1: 0  particle1: 0 iteration2: 1  particle2: 0
# 313/313 [==============================] - 5s 10ms/step - loss: 1.8861 - accuracy: 0.3059 - val_loss: 1.6920 - val_accuracy: 0.3880
# iteration1: 0  particle1: 0 iteration2: 1  particle2: 1
# 313/313 [==============================] - 4s 7ms/step - loss: 1.7925 - accuracy: 0.3483 - val_loss: 1.5210 - val_accuracy: 0.4452
# iteration1: 0  particle1: 0 iteration2: 1  particle2: 2
# 313/313 [==============================] - 4s 7ms/step - loss: 1.8514 - accuracy: 0.3250 - val_loss: 1.6342 - val_accuracy: 0.4088
# iteration1: 0  particle1: 0 iteration2: 2  particle2: 0
# 313/313 [==============================] - 5s 7ms/step - loss: 1.7924 - accuracy: 0.3457 - val_loss: 1.5461 - val_accuracy: 0.4348
# iteration1: 0  particle1: 0 iteration2: 2  particle2: 1
# 313/313 [==============================] - 4s 7ms/step - loss: 1.8165 - accuracy: 0.3320 - val_loss: 1.5516 - val_accuracy: 0.4488
# iteration1: 0  particle1: 0 iteration2: 2  particle2: 2
# iteration1: 2  particle1: 1 iteration2: 2  particle2: 0
# 313/313 [==============================] - 8s 10ms/step - loss: 2.0494 - accuracy: 0.2229 - val_loss: 1.7957 - val_accuracy: 0.3326
# iteration1: 2  particle1: 1 iteration2: 2  particle2: 1
# 313/313 [==============================] - 7s 10ms/step - loss: 2.0490 - accuracy: 0.2261 - val_loss: 1.8087 - val_accuracy: 0.3223
# iteration1: 2  particle1: 1 iteration2: 2  particle2: 2
# 313/313 [==============================] - 7s 10ms/step - loss: 1.9987 - accuracy: 0.2401 - val_loss: 1.7919 - val_accuracy: 0.3394
# iteration1: 2  particle1: 2 iteration2: 0  particle2: 0
# 313/313 [==============================] - 5s 8ms/step - loss: 1.8596 - accuracy: 0.3046 - val_loss: 1.7159 - val_accuracy: 0.3614
# iteration1: 2  particle1: 2 iteration2: 0  particle2: 1
# 313/313 [==============================] - 5s 7ms/step - loss: 1.7519 - accuracy: 0.3583 - val_loss: 1.4726 - val_accuracy: 0.4721
# iteration1: 2  particle1: 2 iteration2: 0  particle2: 2
# 313/313 [==============================] - 5s 8ms/step - loss: 1.8609 - accuracy: 0.3116 - val_loss: 1.6254 - val_accuracy: 0.3947
# iteration1: 2  particle1: 2 iteration2: 1  particle2: 0
# 313/313 [==============================] - 5s 8ms/step - loss: 1.7469 - accuracy: 0.3613 - val_loss: 1.5370 - val_accuracy: 0.4327
# iteration1: 2  particle1: 2 iteration2: 1  particle2: 1
# 313/313 [==============================] - 4s 7ms/step - loss: 1.7771 - accuracy: 0.3498 - val_loss: 1.5837 - val_accuracy: 0.4298
# iteration1: 2  particle1: 2 iteration2: 1  particle2: 2
# 313/313 [==============================] - 4s 7ms/step - loss: 1.7920 - accuracy: 0.3435 - val_loss: 1.5504 - val_accuracy: 0.4371
# iteration1: 2  particle1: 2 iteration2: 2  particle2: 0
# 313/313 [==============================] - 5s 8ms/step - loss: 1.7326 - accuracy: 0.3663 - val_loss: 1.5126 - val_accuracy: 0.4488
# iteration1: 2  particle1: 2 iteration2: 2  particle2: 1
# 313/313 [==============================] - 6s 7ms/step - loss: 1.7351 - accuracy: 0.3701 - val_loss: 1.5389 - val_accuracy: 0.4497
# iteration1: 2  particle1: 2 iteration2: 2  particle2: 2
# 313/313 [==============================] - 5s 8ms/step - loss: 1.8038 - accuracy: 0.3470 - val_loss: 1.6222 - val_accuracy: 0.4090
# Global Best Particle: [5. 5. 3.] [  3.  10.   1.  11.   1.   0.  16. 969.]
# Global Best Fitness (Accuracy): 0.47209998965263367
# total time is 0:09:21.654210

# %%
# Load CIFAR-100 dataset
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data(label_mode='fine')
# Reshape and normalize data
train_images = train_images.reshape((50000, 32, 32, 3)).astype('float32') / 255
test_images = test_images.reshape((10000, 32, 32, 3)).astype('float32') / 255
# Convert labels to one-hot encoded format
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
# Split the training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2)
def create_model(params, conv_layers, pool_layers, dense_layers):
    stride_size_conv = int(params[0])
    filter_size_conv = int(params[1])
    stride_size_pool = int(params[2])
    filter_size_pool = int(params[3])
    padding_pixels_conv = 'same' if int(params[4]) == 1 else 'valid'
    padding_pixels_pool = 'same' if int(params[5]) == 1 else 'valid'
    num_filters = int(params[6])
    num_neurons = int(params[7])

    input_size = 32  # size of the input images

    model = Sequential()

    # Add convolutional layers
    for _ in range(conv_layers):
      if input_size - filter_size_conv < 0:
            break
      model.add(Conv2D(filters=num_filters, kernel_size=(filter_size_conv, filter_size_conv), strides=(stride_size_conv, stride_size_conv), padding=padding_pixels_conv, activation='relu'))
      model.add(Dropout(0.2))  # 20% Dropout
      input_size = (input_size - filter_size_conv) // stride_size_conv + 1

    # Add pooling layers
    for _ in range(pool_layers):
      if input_size - filter_size_pool < 0:
            break
      model.add(MaxPooling2D(pool_size=(filter_size_pool, filter_size_pool), strides=(stride_size_pool, stride_size_pool), padding=padding_pixels_pool))
      input_size = (input_size - filter_size_pool) // stride_size_pool + 1

    if input_size > 0:
        model.add(Flatten())

        # Fully Connected Layers
        for _ in range(dense_layers):
            model.add(Dense(units=num_neurons, activation='relu'))
            model.add(Dropout(0.2))  # 20% Dropout

        model.add(Dense(100, activation='softmax'))

        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    else:
        model = None

    return model
# Running the hybrid PSO-CNN optimization
start_time = datetime.now()
gbest, gbest_l2, gbest_fitness, gbests_fitnesses_l1 = hybrid_MPSO_CNN_level1(t_max1=3, m=3)
end_time = datetime.now()
print(f"Global Best Particle: {gbest} {gbest_l2}\nGlobal Best Fitness (Accuracy): {gbest_fitness}")
print("total time is %s" % (str(end_time - start_time)))
# Out:
# iteration1: 0  particle1: 0 iteration2: 0  particle2: 0
# 313/313 [==============================] - 4s 7ms/step - loss: 4.2862 - accuracy: 0.0436 - val_loss: 3.9849 - val_accuracy: 0.0801
# iteration1: 0  particle1: 0 iteration2: 0  particle2: 1
# 313/313 [==============================] - 5s 7ms/step - loss: 4.3195 - accuracy: 0.0379 - val_loss: 4.0453 - val_accuracy: 0.0671
# iteration1: 0  particle1: 0 iteration2: 0  particle2: 2
# 313/313 [==============================] - 5s 8ms/step - loss: 4.3883 - accuracy: 0.0289 - val_loss: 4.2128 - val_accuracy: 0.0489
# iteration1: 0  particle1: 0 iteration2: 1  particle2: 0
# 313/313 [==============================] - 5s 7ms/step - loss: 4.3999 - accuracy: 0.0265 - val_loss: 4.2311 - val_accuracy: 0.0356
# iteration1: 0  particle1: 0 iteration2: 1  particle2: 1
# 313/313 [==============================] - 4s 7ms/step - loss: 4.3880 - accuracy: 0.0269 - val_loss: 4.2233 - val_accuracy: 0.0404
# iteration1: 0  particle1: 0 iteration2: 1  particle2: 2
# 313/313 [==============================] - 4s 7ms/step - loss: 4.2843 - accuracy: 0.0388 - val_loss: 4.0652 - val_accuracy: 0.0666
# iteration1: 0  particle1: 0 iteration2: 2  particle2: 0
